# %%
import numpy as np
import cv2
from scipy import misc
import os

from piano_detector import *

# %%
for filename in os.listdir("images"):
    if filename.endswith(".jpg"): 
        image = misc.imread(os.path.join("images", filename))
        detectPiano(image, False)
    else:
        continue
# Out:
# Number of octaves detected: 0
# Number of octaves detected: 0
# Number of octaves detected: 0
# Number of octaves detected: 0
# Number of octaves detected: 0
# Number of octaves detected: 0
# Number of octaves detected: 0
# Number of octaves detected: 0
# Number of octaves detected: 0
# Number of octaves detected: 0
# Number of octaves detected: 0
# Number of octaves detected: 0
# Number of octaves detected: 0
# Number of octaves detected: 0
# Number of octaves detected: 0
# Number of octaves detected: 0
# Number of octaves detected: 0
# Number of octaves detected: 0
# Number of octaves detected: 0
# Number of octaves detected: 0
# Number of octaves detected: 0
# Number of octaves detected: 0
# Number of octaves detected: 0
# Number of octaves detected: 0
# Number of octaves detected: 0
# Number of octaves detected: 0
# Number of octaves detected: 0
# Number of octaves detected: 0
# Number of octaves detected: 0
# Number of octaves detected: 0
# Number of octaves detected: 0
# ...
